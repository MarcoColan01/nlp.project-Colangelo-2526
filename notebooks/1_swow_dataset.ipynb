# %%
import sys 
import os
from pathlib import Path

# %%
current_notebook_dir = Path(os.getcwd())
project_root = current_notebook_dir.parent
raw_data_path = project_root / "data" / "raw" / "SWOW_EN.csv"
output_dir = project_root / "data" / "processed"

# %%
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

print(f"Project Root: {project_root}")
print(f"Input File:   {raw_data_path}")
print(f"Output Dir:   {output_dir}")
# Out:
# Project Root: c:\Users\cola0\Desktop\nlp.project-Colangelo-2526
# Input File:   c:\Users\cola0\Desktop\nlp.project-Colangelo-2526\data\raw\SWOW_EN.csv
# Output Dir:   c:\Users\cola0\Desktop\nlp.project-Colangelo-2526\data\processed

# %%
from src.data_processing import process_swow
os.makedirs(output_dir, exist_ok=True)
try:
    process_swow(str(raw_data_path), str(output_dir), test_size=0.05)
    print("\nData Processing is ok.")
except FileNotFoundError:
    print(f"\nERRORE: No found {raw_data_path}.")
# Out:
# 2026-02-05 09:57:14,100 - INFO - Loading dataset from c:\Users\cola0\Desktop\nlp.project-Colangelo-2526\data\raw\SWOW_EN.csv...
# 2026-02-05 09:57:15,613 - INFO - Loaded rows: 1356362. Ok rows after dropna: 1356134
# 2026-02-05 09:57:15,614 - INFO - Data format in progress...
# 2026-02-05 09:57:22,250 - INFO - Splitting dataset (Test size: 0.05)...
# 2026-02-05 09:57:22,542 - INFO - Saving train set on c:\Users\cola0\Desktop\nlp.project-Colangelo-2526\data\processed\swow_train.jsonl (1288327 examples)...
# 2026-02-05 09:57:25,311 - INFO - Saving validation set on c:\Users\cola0\Desktop\nlp.project-Colangelo-2526\data\processed\swow_val.jsonl (67807 examples)...
# 2026-02-05 09:57:25,450 - INFO - Data Processing Complete.
# Data Processing is ok.

# %%
import json
train_file = output_dir / "swow_train.jsonl"

if train_file.exists():
    print(f"\n--- Anteprima: {train_file.name} ---")
    with open(train_file, 'r', encoding='utf-8') as f:
        for i in range(2):
            print(json.loads(f.readline()))
# Out:
# --- Anteprima: swow_train.jsonl ---
# {'prompt': 'Word association task. Input: chasm. Associated words:', 'completion': 'crack, hole, precipice.', 'full_text': 'Word association task. Input: chasm. Associated words:crack, hole, precipice.'}
# {'prompt': 'Word association task. Input: emphasis. Associated words:', 'completion': 'importance, intensity, stress.', 'full_text': 'Word association task. Input: emphasis. Associated words:importance, intensity, stress.'}
